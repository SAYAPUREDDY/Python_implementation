# %% [markdown]
# # 1.Random Intro

# %%
# Generating a random integer from 0 to 100
import numpy as np
from numpy import random
x = random.randint(100)
print(x)
# Out:
# 5

# %%
# Generating random float number
x=random.rand()
print(x)
# Out:
# 0.8474525576333285

# %%
# Generate random array
size=5
x=random.randint(100,size=5)
print(x)
# Out:
# [20 81 33 89 54]

# %%
# generate 2-D array with 3 rows and five elements in each
x=random.randint(100,size=(3,5))
print(x)
# Out:
# [[10 58 40 86 78]
#  [97 86 90 16 65]
#  [ 1 31 86 80 16]]

# %%
# generate a array of floats
x=random.rand(5)
print(x)
# Out:
# [0.11692863 0.12360128 0.95125967 0.2782183  0.56364065]

# %%
# generate 2-D array 
x=random.rand(3,5)
print(x)
# Out:
# [[0.79021308 0.10631349 0.13900443 0.77135865 0.90685558]
#  [0.27933261 0.6801651  0.28771543 0.8378264  0.12736871]
#  [0.20469645 0.20871577 0.73417976 0.56635245 0.90617604]]

# %%
# we can use choice() to get the random number from given array of values
x=random.choice([1,2,3,4,5])
print(x)
# Out:
# 3

# %%
# generate 2-D array
x=random.choice([1,2,3,4,5],size=(3,5))
print(x)
# Out:
# [[4 1 4 2 1]
#  [4 1 4 2 1]
#  [5 5 5 3 4]]

# %% [markdown]
# # 2. Data Distribution

# %%
# can generate the numbers using the probablity and can define the probabbilities using i the choice()
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print(x)
# Out:
# [7 7 5 7 7 5 5 7 3 7 7 5 7 5 7 7 7 7 7 7 7 3 7 5 7 5 7 7 7 5 5 5 7 3 7 5 7
#  5 7 7 5 7 7 7 5 7 3 7 5 3 5 5 7 7 7 5 5 7 7 7 7 3 5 7 5 5 5 5 5 7 5 3 5 5
#  7 7 7 7 7 5 7 7 5 7 7 5 5 7 5 3 7 7 7 7 7 5 7 5 7 5]

# %%
# 2-D array
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))
print(x)
# Out:
# [[7 7 7 7 7]
#  [7 5 3 7 5]
#  [5 5 5 5 3]]

# %% [markdown]
# # 3. Random Permutations

# %% [markdown]
# # Shuffling arrays

# %%
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [2 5 1 3 4]

# %%
# generating the random permutations of arrays
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
print(arr)
# Out:
# [1 3 5 2 4]
# [1 2 3 4 5]

# %% [markdown]
# # 4. Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # plotting a Distrubution Plot(Distplot)

# %%
sns.displot([0,1,2,3,4,5])
plt.show()

# %%
# plotting the distplot without histogram
sns.displot([0, 1, 2, 3, 4, 5], kind='kde')
plt.show()

# %% [markdown]
# # 5. Normal (guassian) Distribution

# %% [markdown]
# # we can use random.normal() method to get a nomral data distribution
# - it has three parameters
# 1. loc = mean(where the peak exsists)
# 2. scale = standard deviation(how flat the graph distribution should be)
# 3. size = the shape of the returned array

# %%
x=random.normal(size=(2,3))
print(x)
# Out:
# [[ 0.06654885 -2.02291062  0.08924932]
#  [-1.41133793 -0.60732408  0.37211596]]

# %%
# generating the random normal distribution with mean at 1 and standard deviation of 2
x=random.normal(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[-0.08928928  3.66225236  2.72271459]
#  [ 2.79247495 -0.9321457  -1.94772362]]

# %%
# visualization of normal distribution
sns.displot(random.normal(size=(1000)),kind='kde')
plt.show()

# %% [markdown]
# # 6. Binomial Distribution
# - Binomial Distribution is a Discrete Distribution.
# - It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
# - It has three parameters:
# 1. n - number of trials.
# 2. p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
# 3. size - The shape of the returned array.

# %%
# given 10 trails for coin toss generate 10 data points
x=random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [4 4 6 7 4 2 5 5 6 6]

# %%
# visualization of binomial distribution
sns.displot(random.binomial(n=10, p=0.5, size=1000),kind='hist')
plt.show()

# %% [markdown]
# # Difference between normal and binomial distribution

# %%
sns.kdeplot(random.normal(loc=50,scale=5,size=1000),label='normal')
sns.kdeplot(random.binomial(n=100,p=0.5,size=1000),label='binomial')
plt.legend()
plt.show()

# %% [markdown]
# # 7. Poisson Distribution
# - It has two parameters:
# 1. lam - rate or known number of occurrences e.g. 2 for above problem.
# 2. size - The shape of the returned array.

# %%
# generate a random 1x10 distribution occurence 2:
from numpy import random
x=random.poisson(lam=2,size=10)
print(x)
# Out:
# [3 1 0 5 1 2 2 2 4 0]

# %%
# visualization of Poisson distribution
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.poisson(lam=2,size=1000))
plt.show()

# %% [markdown]
# # Difference between Normal and Poisson Distribution

# %%
sns.kdeplot(random.normal(loc=50,scale=7,size=1000),label='normal')
sns.kdeplot(random.poisson(lam=50,size=1000),label='poisson')
plt.legend()
plt.show()

# %% [markdown]
# # Dffference between Binomial and Poisson

# %%
sns.kdeplot(random.binomial(n=1000, p=0.01, size=1000),label='binomial')
sns.kdeplot(random.poisson(lam=10, size=1000), label='poisson')
plt.legend()
plt.show()

# %% [markdown]
# # 8. Uniform Distribution
# - It has three parameters:
# 1. a - lower bound - default 0 .0.
# 2. b - upper bound - default 1.0.
# 3. size - The shape of the returned array.

# %%
x=random.uniform(size=(2,3))
print(x)
# Out:
# [[0.24855348 0.67054935 0.51521909]
#  [0.08126029 0.28408325 0.31815343]]

# %%
# visualization of normal distribution
sns.displot(random.uniform(size=1000),kind='kde')

# %% [markdown]
# # 9. Logistic Distribution

# %%
from numpy import random
x=random.logistic(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[-1.59327479 -1.99738952 -2.39873195]
#  [ 3.2813984   0.2087142  16.75427708]]

# %%
# visualization
sns.displot(random.logistic(size=1000),kind='kde')

# %% [markdown]
# # Difference between Logistic and normal distribution

# %%
sns.kdeplot(random.normal(scale=2,size=1000),label='normal')
sns.kdeplot(random.logistic(size=1000),label='logistic')
plt.legend()
plt.show()

# %% [markdown]
# # 10. Multinomial Distribution
# - Multinomial distribution is a generalization of binomial distribution.
# - It has three parameters:
# 1. n - number of possible outcomes (e.g. 6 for dice roll).
# 2. pvals - list of probabilties of outcomes (e.g. [1/6, 1/6, 1/6, 1/6, 1/6, 1/6] for dice roll).
# 3. size - The shape of the returned array.

# %%
x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
print(x)
# Out:
# [0 0 1 2 1 2]

# %% [markdown]
# # 11. Exponential Distribution
# Exponential distribution is used for describing time till next event e.g. failure/success etc.
# - It has two parameters:
# 1. scale - inverse of rate ( see lam in poisson distribution ) defaults to 1.0.
# 2. size - The shape of the returned array.

# %%
x=random.exponential(scale=2,size=(2,3))
print(x)
# Out:
# [[0.61251276 1.52619553 0.07512709]
#  [1.37780143 1.60840122 3.75592386]]

# %%
# visualization of Exponential distribution
sns.displot(random.exponential(size=1000),kind='kde')
plt.show()

# %% [markdown]
# # 12. Chi Square Distribution
# It is used as a basis to verify the hypothesis
# - It has two parameters:
# 1. df - (degree of freedom)
# 2. size- the shape of returned array

# %%
x=random.chisquare(df=2,size=(2,3))
print(x)
# Out:
# [[2.78269395 4.16665347 1.80521022]
#  [1.63679959 0.01051839 0.25613495]]

# %%
# Visualization of Chi Square Distribution
sns.displot(random.chisquare(df=1,size=1000),kind='kde')
plt.show()

# %% [markdown]
# # 13. Rayleigh Distribution
# It is used in signal processing
# - It has two parameters:
# 1. scale - (standard deviation) decides how flat the distribution will be default 1.0).
# 2. size - The shape of the returned array.

# %%
x=random.rayleigh(scale=2,size=(2,3))
print(x)
# Out:
# [[1.8494539  1.34812211 2.40275447]
#  [3.35418425 2.08292681 1.01336253]]

# %%
# visualization of rayleigh distribution
sns.displot(random.rayleigh(size=1000),kind='kde')
plt.show()

# %% [markdown]
# # 14. Pareto Distribution
# A distribution following Pareto's law i.e. 80-20 distribution (20% factors cause 80% outcome).
# - It has two parameter:
# 1. a - shape parameter.
# 2. size - The shape of the returned array.

# %%
x = random.pareto(a=2, size=(2, 3))
print(x)
# Out:
# [[2.35767172 0.56263957 0.03783212]
#  [0.41023379 0.12210826 0.24342106]]

# %%
# visualization of pareto distribution
sns.displot(random.pareto(a=2, size=1000), kind='hist')

# %% [markdown]
# # 15. Zipf Distribution
# It is based on the zipf's law
# zipf's law:In a collection, the nth common term is 1/n times of the most common term. E.g. the 5th most common word in English occurs nearly 1/5 times as often as the most common word.
# - It has two parameters:
# 1. a - distribution parameter.
# 2. size - The shape of the returned array.

# %%
x = random.zipf(a=2, size=(2, 3))
print(x)
# Out:
# [[3 1 1]
#  [4 3 2]]

# %%
x=random.zipf(a=2,size=1000)
sns.displot(x[x<10],kind='hist')
plt.show()
